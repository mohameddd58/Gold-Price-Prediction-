# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
gold_data = pd.read_csv('gld_price_data.csv')

# %%
gold_data.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
gold_data.shape
# Out:
# (2290, 6)

# %%
gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
X = gold_data.drop(['Date','GLD'],axis=1)
Y = gold_data['GLD']

# %%
print(X)
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
print(Y)
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
LinearModel = LinearRegression()

# %%
LinearModel.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
test_data_prediction = LinearModel.predict(X_test)
print(test_data_prediction)
# Out:
# [159.45290968  81.50858067 113.4868037  128.55153817 126.20403783
#  141.31818338 165.49416492 124.44197659 113.95389904 122.9965895
#  113.95492464 174.89529849 132.66890174 159.24793304 118.8791679
#  122.14315717 150.37153054 161.27175405 152.2792036  162.19946709
#  145.88372183 118.07669395 180.21729122 178.13331554 123.51701986
#   98.82914322  76.63486248 119.38435511 113.85027665 159.25706609
#   93.76037617 120.05334649  88.61086583 114.28801659 112.77954274
#  144.19518102 118.78252489 115.87334354 144.06409553 113.81864246
#  100.49676727  89.42842238 120.36720699 110.47635305 146.4894628
#  119.30321261 110.99311348 111.3386287   96.48139076 123.40842816
#   79.51413425 115.36111603 121.78896764 114.55367722 120.9074622
#  117.10612464 152.31198525 182.7735091  196.73570503  91.06670951
#  101.92097594  87.48443506  94.33158785 119.17357764 121.8935122
#  125.85678089 163.2699701  122.91100556 113.55098736 104.06905043
# ...

# %%
error_score = metrics.r2_score(Y_test, test_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.8657886565869237

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error (Y_test, test_data_prediction)

# %%
mse
# Out:
# 70.7889007972153

# %%
from sklearn.svm import SVR

# %%
SVRModel = SVR(C = 20 ,kernel = 'linear')

# %%
SVRModel.fit(X_train,Y_train)
# Out:
# SVR(C=20, kernel='linear')

# %%
svr_prediction = SVRModel.predict(X_test)

# %%
svr_prediction
# Out:
# array([146.01908366,  77.94138293, 108.76406412, 121.72341688,
#        119.63980795, 130.53911836, 151.75364708, 119.17654005,
#        108.70479505, 116.44064108, 108.96063112, 159.64619946,
#        124.03370292, 145.76510526, 112.72770603, 116.45684254,
#        138.68521736, 147.76943701, 139.91828538, 148.58698957,
#        134.92644862, 111.86947751, 164.21957397, 162.33120369,
#        118.63728966,  95.43830757,  74.71602531, 113.49731027,
#        108.66781095, 146.01155616,  90.75536652, 115.66481493,
#         82.92704032, 109.47833222, 106.2161256 , 133.09181888,
#        112.72153729, 110.70321022, 132.87882388, 108.82758124,
#         96.59477498,  84.60642682, 115.96179645, 104.56088839,
#        134.81012263, 113.46257986, 106.6290908 , 106.67806166,
#         91.45000792, 116.85600719,  77.46170679, 109.89720689,
#        115.79563716, 109.44583906, 116.01260996, 110.87650353,
#        140.53805772, 166.28387421, 177.67936385,  86.72060754,
# ...

# %%
mse_svr = mean_squared_error (Y_test, svr_prediction)

# %%
mse_svr
# Out:
# 118.98764332936751

# %%
error_score_svr = metrics.r2_score(Y_test, svr_prediction)
print("R squared error : ", error_score_svr)
# Out:
# R squared error :  0.7744068451276391
